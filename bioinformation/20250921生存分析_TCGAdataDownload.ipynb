# %% [markdown]
# TCGA数据下载地址：https://portal.gdc.cancer.gov/

# %% [markdown]
# - https://xenabrowser.net/datapages/
# - 可以在以上网站搜索疾病，然后下载相应的TCGA数据集（基因表达数据和生存数据）。
#
# - 本教程的参考：https://mp.weixin.qq.com/s/P1oJS3ONAK-37H09er7nFg
# ### 自己的流程:
# - 1. 下载TCGA数据集，选择相应的疾病，下载相应的基因表达数据和生存数据。(../data/job.sh)
# - 2. 利用R进行生存分析(20250921_生存分析.R)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

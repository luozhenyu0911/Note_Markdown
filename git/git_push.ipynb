# %% [markdown]
# - 2. ssh -T git@github.com 一直在等待，没有结果出来，请检查网络连接是否正常。如有：Hi luozhenyu0911! You've successfully authenticated, but GitHub does not provide shell access.

# %% [markdown]
# ## git push不上问题
# - remote: Write access to repository not granted.
# - fatal: unable to access 'https://github.com/luozhenyu0911/plotting.git/': The requested URL returned error: 403

# %% [markdown]
# ### 解决方法
# - 这是因为生成的token 没有写入权限
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

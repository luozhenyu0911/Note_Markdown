# %% [markdown]
# ### 1. 更新系统并安装依赖
# ```bash
# sudo apt update
# sudo apt upgrade -y
# sudo apt install wget curl -y
# ```
# ### 2. 下载 Miniconda 安装脚本
# ```bash
# # 下载最新版 Miniconda（Python 3）
# wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
#
# # 或者指定特定版本
# # wget https://repo.anaconda.com/miniconda/Miniconda3-py39_4.9.2-Linux-x86_64.sh
# ```
# ### 3. 安装 Miniconda
# ```bash
# # 执行安装脚本
# bash Miniconda3-latest-Linux-x86_64.sh
# ```
#
# ### 4. 配置jupter环境变量
# ```bash
# # 安装Jupyter Notebook及其插件
# conda install jupyter notebook -y
# python -m ipykernel install --user
# conda install -c conda-forge jupyter_contrib_nbextensions -y
# conda install jupyterthemes -y
# ```
# - CondaToSNonInteractiveError: Terms of Service have not been accepted for the following channels. Please accept or remove them before proceeding:
#     - https://repo.anaconda.com/pkgs/main
#     - https://repo.anaconda.com/pkgs/r
# 如果遇到此错误，请执行以下命令：
# ```bash
# conda config --set always_yes yes
# conda config --set auto_update_conda false
# ```
#
# ### 5. 配置Jupyter Notebook主题
# ```bash
# # 安装jupyterthemes
# pip install jupyterthemes
#
# # 启用主题
# jt -t chesterish -T -cellw 90% -fs 14 -tfs 14 -nfs 14 -cellw 90% -T
# ```
#
# ### 然后在Ubuntu输入code . 进入vscode
# ### 随后在vscode上安装jupyter
# ![image.png](attachment:image.png)
# ### 随后就可以在vscode的内核中选择jupter内核中的conda中的python
# ![image-2.png](attachment:image-2.png)
